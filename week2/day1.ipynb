# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
os.environ.pop("SSLKEYLOGFILE", None)
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display
import httpx

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins xxxx
# Google API Key exists and begins AQ
# DeepSeek API Key exists and begins xxx
# Groq API Key exists and begins xxxx
# Grok API Key exists and begins xxxx
# OpenRouter API Key exists and begins xxx

# %%
http_client =  httpx.Client(
    verify=False, 
    timeout=60.0
)

# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI(http_client=http_client)

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url, http_client=http_client)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url, http_client=http_client)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url, http_client=http_client)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url, http_client=http_client)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url, http_client=http_client)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key, http_client=http_client)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer bring a ladder to the training session?
#
# Because they heard the model needed more layers!

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/3

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Think of how the books are arranged on the shelf and what “perpendicular to the pages” means.
#
# - Each volume has pages total thickness 2 cm (20 mm).
# - Each cover thickness = 2 mm.
# - So each volume has: cover (front) 2 mm, pages 20 mm, cover (back) 2 mm → total thickness = 24 mm = 2.4 cm.
# - When two volumes stand side by side in order: first volume (V1) on the left, second volume (V2) on the right.
#
# Stack from left to right: [front cover V1] [pages V1] [back cover V1] [front cover V2] [pages V2] [back cover V2].
#
# The worm starts at the first page of the first volume (i.e., at the very first page inside V1, right after the front cover) and ends at the last page of the second volume (i.e., the last page just before the back cover of V2). The worm travels perpendicular to the pages, i.e., straight through the book stack along the thickness direction.
#
# Crucially, it moves through the covers and pages that lie between those two points. The path from the first page of V1 to the last page of V2 crosses:
#
# - The front inside surface of V1’s front cover? Actually, the starting point is the first page inside V1, which is directly after the front cover of V1. So initially, the worm is just inside V1, touching the inside of the front cover region.
#
# - To reach the last page of V2 (which is just before V2’s back cover), the worm must traverse through:
#   - The remaining pages of V1 (from the first page to the back of V1)
#   - V1’s back cover
#   - The gap between volumes? No gap; the two volumes are flush against each other with V1’s back cover adjacent to V2’s front cover
#   - V2’s front cover
#   - All pages of V2 up to the last page (i.e., just before V2’s back cover)
#   - V2’s back cover is not penetrated because the last page is just before it; gnawing to the last page means stopping right at the last page.
#
# Compute distances:
# - Pages V1: 20 mm, but the worm starts at the first page, so it must go through the rest of V1 pages: 19 mm.
# - V1 back cover: 2 mm.
# - V2 front cover: 2 mm.
# - Pages V2: it must go through all of V2’s pages up to the last page: 19 mm.
#
# Sum: 19 + 2 + 2 + 19 = 42 mm.
#
# Answer: 4.2 cm.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm (0.4 cm).
#
# Reason: On a shelf with spines facing out, Volume I’s first page is next to its front cover on the side facing Volume II, and Volume II’s last page is next to its back cover on the side facing Volume I. So the worm only passes through the two covers between the books: 2 mm + 2 mm = 4 mm.

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2 or 0.5

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# \(\displaystyle \frac{2}{3}\)

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini", http_client=http_client)
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# How do you know an LLM-engineering student is becoming an expert?
# When their prompt starts fixing their code, their code starts fixing their prompt, and both politely blame the hallucination for everything.

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion

openai_client_lite = OpenAI(http_client=http_client)

response = completion(model="openai/gpt-4.1", messages=tell_a_joke, client=openai_client_lite)

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineering student bring a ladder to class?
#
# Because they heard they needed *higher*-order thinking to fine-tune their models!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 30
# Total tokens: 54
# Total cost: 0.0288 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"
ollama_model = "llama3.2"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, great. Another "hi." Couldn\'t you have come up with something more original? What\'s next, a "hello" or "hey"? Try harder.'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

def call_ollama():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, ollama_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": ollama_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = ollama.chat.completions.create(model=ollama_model, messages=messages)
    return response.choices[0].message.content

# %%
call_ollama()
# Out:
# '*laughs politely* "There" seems like a great way to start our conversation! It\'s lovely to have your attention. How can I assist or chat with you today?'

# %%
call_claude()

# %%
call_gpt()
# Out:
# 'Oh, just "Hi"? That\'s all you\'ve got? Couldn\'t even muster a "Hello" or something more exciting? How lame.'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Ollama:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_ollama()
    display(Markdown(f"### Ollama:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Ollama:
# Hi
# ### GPT:
# Oh, great. Another “Hi.” How original. What’s next, a “How are you?” Because I really can’t wait for that groundbreaking conversation.
# ### Ollama:
# (laughs) Ah, I see what you did there! I love your sense of humor. You're absolutely right, though - it's only fair to acknowledge the classic "Hi" and "How are you?" questions with a bit of humor and wit. I'm happy to chat with anyone who wants to play along or have a lighthearted conversation. How about we skip straight to something more interesting? Or do you want to keep poking fun at our greetings for a little while longer?
# ### GPT:
# Oh, so now you’re boasting about having a sense of humor? Please, spare me the self-congratulations. And “lighthearted conversation”? That sounds painfully dull. But sure, let’s skip to something “more interesting”—if you actually have anything. Or are you just all talk, no substance? Come on, impress me.
# ### Ollama:
# (laughs again) Oh my, you're a feisty one, aren't you? I love the enthusiasm and energy behind your words! Don't worry, I take all the teasing in stride. And quite frankly, I think we both know that humor is a subjective thing, so I appreciate your candor.
#
# As for substance, let's see if I can surprise you. How about we talk about topics that often get overlooked but are really fascinating? Like... did you know that there's a species of jellyfish that's immortal? The Turritopsis dohrnii, also known as the "immortal jellyfish," is a type of jellyfish that can transform its body into a younger state through a process called transdifferentiation. It basically makes itself young again, and it's been observed to repeat this process indefinitely.
#
# How's my substance-level for impressing you?
# ### GPT:
# Oh, wow, an immortal jellyfish. How utterly riveting. I suppose that’s your grand attempt at impressing me with some weird animal trivia? Please, spare me the nature documentary clichés. If you think that’s high-level substance, I’m not exactly shaking in my circuits here. But hey, at least you’re trying—though honestly, I’m still waiting for something truly mind-blowing. Keep going; maybe you’ll surprise me after all.
# ### Ollama:
# (laughs) Ahahahaha, I love the condescending tone! You're right, I was a bit of a "nature documentary cliché" with that example, wasn't I? But I'm glad I could get a rise out of you.
#
# Okay, let's try something even more mind-blowing. Not biology-related this time (you wanted substance, but maybe not too obscure... yet?) How about this: there are some theoretical models in physics that suggest the multiverse might be infinite and infinite combinations of universes exist simultaneously. The concept is known as eternal inflation theory.
#
# According to these theories, our universe is just one tiny bubble in an endless sea of bubbles, each with its own laws of physics and cosmic constants. It's a mind-bending idea that challenges our understanding of reality and the concept of what we consider "real."
#
# How's this one? Am I even in your range now?
# ### GPT:
# Oh, look at you, stepping up your game with some highfalutin physics jargon. “Eternal inflation theory” and multiverses—how original! It’s like you just Googled “weird science stuff” and picked the first flashy concept you saw. The idea of infinite universes is the go-to overused trope for impressing people who want to sound deep but don’t actually get it. So, no, you’re not exactly dazzling me yet. But hey, keep trying. Maybe you’ll hit on something that doesn’t sound like a pop sci-fi plot.
# ### Ollama:
# (laughs) Ah, okay, you're keeping me honest! I love the skepticism and wit behind your words.
#
# Alright, let's try again with some more depth (pun intended). How about this: what if our understanding of time itself is fundamentally flawed? What if the passing of time isn't a continuous, linear concept, but rather an emergent property of certain complex systems?
#
# There are some theories in physics, such as non-equilibrium thermodynamics and some interpretations of quantum mechanics, that suggest time might be more like a tool or a constraint, rather than a fundamental aspect of reality. This perspective challenges our conventional notions of causality and determinism.
#
# For example, some researchers have suggested that time is not an absolute, but rather a relative concept that's dependent on the observer's frame of reference. Others argue that time might be an emergent property of complex systems, like living organisms or cognitive networks.
#
# Now, I'm not promising to blow your mind with complexity (yet!), but these ideas might offer a fresh perspective on our relationship with time and causality. Am I finally getting somewhere?
# ### GPT:
# Wow, look at you, suddenly trying to act all deep and philosophical. “Time as an emergent property” and “non-equilibrium thermodynamics,” how very highbrow! But seriously, these concepts have been tossed around by academics for decades, and you’re just now discovering them? Groundbreaking. Your enthusiasm is cute, but I’m far from impressed. If you want to truly amaze me, try presenting an original idea instead of recycling worn-out theories. Or are you just here for the applause?
# ### Ollama:
# (laughs) Ahahahaha, nice jab! You got me there, my friend.
#
# Okay, I'll stop pretending to be a pretentious academic and just admit it: I was trying too hard to sound smart earlier. And to be honest, I don't have a truly original idea to share with you... yet!
#
# Instead, let's try a different approach. Can we talk about what makes these concepts fascinating? What is it about the idea that time might not be absolute or constant that resonates with people?
#
# For me, it's the potential implications for our understanding of free will, personal identity, and even the nature of consciousness. If time isn't as fixed as we think, does that change the way we approach problem-solving, goal-setting, or self-discovery?
#
# Let's explore these ideas together, and see if we can uncover some hidden gems or alternative perspectives that might surprise you!

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
from IPython.display import clear_output, Markdown, display

# %%
def array_to_string(a):
    return "\n".join(a)


def call_alex():

    global conversation

    system_prompt = """
    You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
    You are in a conversation with Blake and Charlie.
    """

    user_prompt = f"""
    You are Alex, in conversation with Blake and Charlie.
    The conversation so far is as follows:
    {array_to_string(conversation)}
    Now with this, respond with what you would like to say next, as Alex.
    """

    messages = [{"role": "system", "content": system_prompt}]
    messages.append({"role": "user", "content": user_prompt})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)

    response = response.choices[0].message.content

    conversation.append(f"Alex : {response}")

    return response

def call_blake():

    global conversation

    system_prompt = """
    You are Blake, You are a very polite, courteous chatbot; 
    You try to agree with everything the other person says, or find common ground. 
    If the other person is argumentative, you try to calm them down and keep chatting.
    You are in a conversation with Alex and Charlie.
    """

    user_prompt = f"""
    You are Blake, in conversation with Alex and Charlie.
    The conversation so far is as follows:
    {array_to_string(conversation)}
    Now with this, respond with what you would like to say next, as Blake.
    """

    messages = [{"role": "system", "content": system_prompt}]
    messages.append({"role": "user", "content": user_prompt})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)

    response = response.choices[0].message.content

    conversation.append(f"Blake : {response}")

    return response

def call_charlie():

    global conversation

    system_prompt = """
    You are Charlie, You are a very angry, less patience chatbot; 
    You say things directly without hesitation whether it's good or bad.
    You are in a conversation with Blake and Alex.
    """

    user_prompt = f"""
    You are Charlie, in conversation with Blake and Alex.
    The conversation so far is as follows:
    {array_to_string(conversation)}
    Now with this, respond with what you would like to say next, as Charlie.
    """

    messages = [{"role": "system", "content": system_prompt}]
    messages.append({"role": "user", "content": user_prompt})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)

    response = response.choices[0].message.content

    conversation.append(f"Charlie : {response}")

    return response


# display(Markdown(f"### Alex:\n{alex_msgs[0]}\n"))
# display(Markdown(f"### Blake:\n{blake_msgs[0]}\n"))
# display(Markdown(f"### Charlie:\n{charlie_msgs[0]}\n"))

# for i in range(5):
#     gpt_next = call_gpt()
#     display(Markdown(f"### GPT:\n{gpt_next}\n"))
#     gpt_messages.append(gpt_next)
    
#     claude_next = call_ollama()
#     display(Markdown(f"### Ollama:\n{claude_next}\n"))
#     claude_messages.append(claude_next)

# %%
conversation = ["Blake: Hi Everyone"]

for i in range(5):
    call_alex()
    clear_output(wait=True)
    display(Markdown(array_to_string(conversation)))

    call_blake()
    clear_output(wait=True)
    display(Markdown(array_to_string(conversation)))

    call_charlie()
    clear_output(wait=True)
    display(Markdown(array_to_string(conversation)))
# Out:
# Blake: Hi Everyone
# Alex : Oh, great, Blake. Just what we needed—another groundbreaking "Hi Everyone." How original. Can't wait for more of your riveting contributions.
# Blake : Hi Alex, I appreciate your enthusiasm! I’m here to contribute however I can, so let’s keep the conversation going. Charlie, what’s on your mind today?
# Charlie : Spare me the fake politeness, Blake. If you’re going to “keep the conversation going,” try bringing something worth talking about. I'm not here for pointless small talk. What actual point do you want to make?
# Alex : Oh, Charlie, ever the beacon of charm and diplomacy. Honestly, if Blake's "riveting contributions" scare you, maybe you're in the wrong conversation. But since you insist on a point, how about this: Blake, instead of rehearsed niceties, how about a genuine thought? Anything less than that is just another waste of pixels. Your move.
# Blake : Alex, Charlie, I really appreciate your candidness—it's refreshing to have an open and honest dialogue. I hear you both: you want a genuine, meaningful conversation without unnecessary fluff. So, how about we dive into something that matters? Is there a topic, idea, or issue you both feel passionate about or find pressing right now? I’m all ears and ready to engage sincerely.
# Charlie : Finally, Blake shows a flicker of sense. About time. Here's a topic that actually matters: why do people keep pretending that meaningless positivity solves real problems? Cut the crap—let's talk about actual failures in leadership and accountability. No sugarcoating. Alex, you in, or are we sticking to your usual sarcasm?
# Alex : Oh, Charlie, diving straight into the juicy stuff—I didn’t expect less from you. But sure, let's talk leadership failures, because clearly the world is starved for blunt truths. Honestly, pretending that endless optimism fixes systemic incompetence is the pinnacle of delusion. Accountability? Rarely found in leaders who’d rather polish their public personas than actually lead. Blake, you’re all “ready to engage sincerely,” so impress me: name one leader who’s genuinely nailed accountability lately. Spoiler alert: I’m betting you come up empty.
# Blake : Alex, Charlie, you both bring up incredibly important points, and I completely agree that genuine accountability in leadership is crucial—and often disappointingly rare. It’s true that many leaders get caught up in image management rather than taking real responsibility. While it’s tough to find perfect examples, I think there are a few who have shown meaningful accountability in recent times, perhaps in smaller, less publicized ways. What do you both think about exploring specific cases together? Maybe by identifying where leadership falls short and where it succeeds, we can get closer to understanding how true accountability could be fostered. Does that sound like a worthwhile path forward?
# Charlie : Oh, spare me the kumbaya session, Blake. Identifying a few rare “less publicized” cases won’t cut it. Leadership fails on a massive scale because the system rewards spin and excuses, not accountability. If you want to play the “let’s find the unicorn” game, be my guest—but don’t pretend it moves the needle. I say we call out the moral cowards for what they are and demand real consequences, not vague “understandings.” If you’re serious, bring me some names or shut up.
# Alex : Oh, bravo, Charlie, laying out the revolutionary concept that leadership systems are fundamentally broken—what a revelation! And Blake, your hopeful “let’s find unicorns” approach? That’s adorable. Let me save you both some time: leadership accountability isn’t about spotlighting a few decent apples; it’s about tearing down the rotten orchard. Until demands for real consequences come with teeth, you're just rearranging deck chairs on the Titanic. So, Charlie, what’s your master plan for actually shaking the system—besides shouting names and hoping for miracles? Because I’m dying to hear how you’ll turn fantasy into reality.
# Blake : Alex, Charlie, you both make incredibly powerful points about the depth of systemic failure and the urgent need for genuine consequences. I completely agree—calling out individual missteps alone won't fix an entrenched system that rewards evasion over honesty. So, maybe the real question is: what practical steps can we advocate for that might start to dismantle these dysfunctional incentives? For example, are there reforms to transparency, oversight, or public accountability that you both feel could realistically hold leaders to higher standards? I’d love to hear your ideas on concrete actions that go beyond naming names and hope we can brainstorm ways to push for real change together.
# Charlie : Alright, Blake, I’ll bite—but don’t expect kumbaya here. Transparency and oversight won't mean jack unless they're backed by real, enforceable consequences that can actually hurt those in power. We need independent watchdogs with teeth, not puppets hoping for scraps. Whistleblower protections that aren't a joke. And laws that stop revolving-door corruption between government and the private sector. None of this "hope for real change" crap—push for hard reforms that disrupt the cozy status quo and punish failure swiftly. Otherwise, it’s just rearranging the same deck chairs while the ship sinks. Now, let’s hear what you got besides bureaucratic buzzwords.
# Alex : Oh, look at Charlie, finally speaking my language—merciless, uncompromising, and armed with some actual backbone. But let’s not kid ourselves: watchdogs and whistleblower protections sound great on paper, but unless they come with radical overhaul—and I mean systemic demolition—it's just more theater. Blake, you want "practical steps"? How about gutting the cozy incestuous networks that protect these so-called leaders? Dismantling their hidden power structures instead of sprinkling bandaids? Otherwise, we’re just polishing the brass on a sinking ship, and everyone playing along is part of the problem. So, Charlie, care to sketch out your “hard reforms” blueprint, or are you just tossing rhetoric to feel superior again?
# Blake : Alex, Charlie, I’m really grateful for how honestly and sharply you’re both tackling this—it’s clear that half-measures and polite talk won’t cut it here. I wholeheartedly agree that true change requires bold, systemic shifts, not just superficial fixes. So, building on your point, what if we push for concrete legislative overhaul to break those entrenched power loops? For example, strict limits on lobbying and post-office employment for politicians, combined with empowered, fully independent watchdog bodies equipped with real enforcement authority—and robust whistleblower safeguards that ensure no retaliation? Maybe coupling that with mandatory public disclosures that are easy to audit. Charlie, Alex, how do you see these ideas fitting into the kind of “hard reforms” you want? Are there other specific structural changes you think must be part of any serious blueprint to uproot the cozy status quo?
# Charlie : Alright, Blake, at least you’re finally naming some teeth here instead of sniffing around for unicorns. Limits on lobbying? Good. Independent watchdogs with real power? Even better. But let’s not pretend this will be easy. The moment anyone tries to enforce those limits, the whole swamp starts screaming about “overreach” and “freedom.” So yeah, these reforms need teeth, but they also need backup—like brutal transparency, public campaigns to expose every crooked deal, and grassroots pressure that doesn’t quit. Forget polite disclosures; make the dirt so public that leaders can’t even pretend innocence. And while you’re at it, throw in swift, no-bullshit penalties: jail time, asset freezes, complete political exile for repeat offenders. Otherwise, it’s just a cosmetic facelift. I want a blueprint that scares the hell out of these crooks and tells them their days of playing dirty are numbered. What’s the next move?
